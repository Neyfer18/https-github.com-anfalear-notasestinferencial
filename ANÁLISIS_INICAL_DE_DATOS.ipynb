# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar archivo CSV
df = pd.read_csv("Nacimientos_20250206.csv")

# Información básica
print("Información del dataset")
print(df.info())
print("Primeras filas del dataset")
print(df.head())
print("Resumen estadístico del dataset")
print(df.describe())
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Periodo                      928 non-null    int64
#  1   Departamento Nacimiento      928 non-null    object
#  2   Municipio                    928 non-null    object
#  3   Area                         928 non-null    object
#  4   Sexo                         928 non-null    object
#  5   Peso                         928 non-null    int64
#  6   Talla                        928 non-null    int64
#  7   Fecha_Nacimiento             928 non-null    object
#  8   Hora_Nacimiento              928 non-null    object
#  9   Tiempo_Gestación             927 non-null    float64
#  10  Número_Consultas_Prenatales  928 non-null    int64
#  11  Tipo_Parto                   928 non-null    object
# ...

# %%
# Valores faltantes
print("\nValores faltantes por columna:")
print(df.isnull().sum())

# Visualización de nulos
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de datos faltantes")
plt.show()
# Out:
# Valores faltantes por columna:
# Periodo                         0
# Departamento Nacimiento         0
# Municipio                       0
# Area                            0
# Sexo                            0
# Peso                            0
# Talla                           0
# Fecha_Nacimiento                0
# Hora_Nacimiento                 0
# Tiempo_Gestación                1
# Número_Consultas_Prenatales     0
# Tipo_Parto                      0
# Multiplicidad_Embarazo          0
# Edad_Madre                      0
# Régimen_Seguridad_Social        0
# EPS                            65
# Edad Padre                      2
# dtype: int64

# %%
# 3. Eliminar filas con datos faltantes y verificar limpieza

# Eliminar filas con datos faltantes
df_filtrado = df.dropna()

# Mostrar el número de filas después de la limpieza
print(f"\nNúmero de filas después de eliminar datos faltantes: {df_filtrado.shape[0]}")

# Identificar y mostrar el número de datos faltantes por columna
faltantes = df_filtrado.isnull().sum()
print("\nDatos faltantes por columna después de la limpieza:")
print(faltantes)

# Visualizar el mapa de calor de datos faltantes (debería estar vacío si la limpieza fue exitosa)
plt.figure(figsize=(10, 2))
sns.heatmap(df_filtrado.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de datos faltantes después de la limpieza")
plt.tight_layout()
# plt.savefig("mapa_datos_faltantes.png") # Quitar comentario si se quiere guardar la figura
plt.show()
# Out:
# Número de filas después de eliminar datos faltantes: 861
#
# Datos faltantes por columna después de la limpieza:
# Periodo                        0
# Departamento Nacimiento        0
# Municipio                      0
# Area                           0
# Sexo                           0
# Peso                           0
# Talla                          0
# Fecha_Nacimiento               0
# Hora_Nacimiento                0
# Tiempo_Gestación               0
# Número_Consultas_Prenatales    0
# Tipo_Parto                     0
# Multiplicidad_Embarazo         0
# Edad_Madre                     0
# Régimen_Seguridad_Social       0
# EPS                            0
# Edad Padre                     0
# dtype: int64
# /tmp/ipython-input-1209801244.py:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Identify categorical columns
categorical_cols = df_filtrado.select_dtypes(include=['object', 'category']).columns

print("Columnas categóricas:")
print(categorical_cols)
# Out:
# Columnas categóricas:
# Index(['Departamento Nacimiento', 'Municipio', 'Area', 'Sexo',
#        'Fecha_Nacimiento', 'Hora_Nacimiento', 'Tipo_Parto',
#        'Multiplicidad_Embarazo', 'Régimen_Seguridad_Social', 'EPS'],
#       dtype='object')

# %%
# Generate plots for categorical variables
for col in categorical_cols:
    print(f"\nGenerando gráficos para la columna: {col}")

    # Pie chart
    plt.figure(figsize=(8, 8))
    df_filtrado[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribución de {col}')
    plt.ylabel('')  # Remove default 'ylabel'
    plt.show()

    # Bar chart
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df_filtrado, y=col, order=df_filtrado[col].value_counts().index, palette='viridis')
    plt.title(f'Conteo de {col}')
    plt.xlabel('Conteo')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# Generando gráficos para la columna: Departamento Nacimiento
# /tmp/ipython-input-1991731027.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_filtrado, y=col, order=df_filtrado[col].value_counts().index, palette='viridis')
# Generando gráficos para la columna: Municipio
# /tmp/ipython-input-1991731027.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_filtrado, y=col, order=df_filtrado[col].value_counts().index, palette='viridis')
# Generando gráficos para la columna: Area
# /tmp/ipython-input-1991731027.py:14: FutureWarning:
#
# ...

# %%
# Identify numerical columns
numerical_cols = df_filtrado.select_dtypes(include=np.number).columns

print("Columnas numéricas:")
print(numerical_cols)
# Out:
# Columnas numéricas:
# Index(['Periodo', 'Peso', 'Talla', 'Tiempo_Gestación',
#        'Número_Consultas_Prenatales', 'Edad_Madre', 'Edad Padre'],
#       dtype='object')

# %%
# Generate histograms and box plots for numerical variables
for col in numerical_cols:
    print(f"\nGenerando gráficos para la columna: {col}")

    # Histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df_filtrado, x=col, kde=True)
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.show()

    # Box plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df_filtrado, y=col)
    plt.title(f'Diagrama de caja de {col}')
    plt.ylabel(col)
    plt.show()
# Out:
# Generando gráficos para la columna: Periodo
# Generando gráficos para la columna: Peso
# Generando gráficos para la columna: Talla
# Generando gráficos para la columna: Tiempo_Gestación
# Generando gráficos para la columna: Número_Consultas_Prenatales
# Generando gráficos para la columna: Edad_Madre
# Generando gráficos para la columna: Edad Padre

# %% [markdown]
# Usar rango intercuatilico IQR para verificar y eliminar datos atipicos outliers

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Identify numerical columns from the cleaned dataframe
numerical_cols_cleaned = df_cleaned.select_dtypes(include=np.number).columns

print("Generando gráficos Q-Q para las columnas numéricas del dataset limpio:")

for col in numerical_cols_cleaned:
    print(f"\n--- Gráfico Q-Q para la columna: {col} ---")
    plt.figure(figsize=(8, 6))
    sm.qqplot(df_cleaned[col].dropna(), line='s')
    plt.title(f'Gráfico Q-Q de {col}')
    plt.show()
# Out:
# Generando gráficos Q-Q para las columnas numéricas del dataset limpio:
#
# --- Gráfico Q-Q para la columna: Periodo ---
# --- Gráfico Q-Q para la columna: Peso ---
# --- Gráfico Q-Q para la columna: Talla ---
# --- Gráfico Q-Q para la columna: Tiempo_Gestación ---
# --- Gráfico Q-Q para la columna: Número_Consultas_Prenatales ---
# --- Gráfico Q-Q para la columna: Edad_Madre ---
# --- Gráfico Q-Q para la columna: Edad Padre ---
